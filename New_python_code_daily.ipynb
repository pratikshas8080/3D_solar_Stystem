# %% [markdown]
# <a href="https://colab.research.google.com/github/pratikshas8080/3D_solar_Stystem/blob/master/New_python_code_daily.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt 

#data for a three dimensional line
ax=plt.axes(projection='3d')
z=np.linspace(0,15,1000)
x=np.sin(z)
y=np.cos(z)
ax.plot3D(x,y,z, 'red')

#Data for three dimensional scattered points
z=15 * np.random.random(100)
x=np.sin(z) + 0.1 * np.random.randn(100)
y=np.cos(z) + 0.1 * np.random.randn(100)

ax.scatter3D(x,y, c=z, cmap='Greens')
plt.show()

# %%
#program to display the fibanacci sequence up to n-th term
nterms=int(input("How many terms??"))

#first two terms 
n1, n3= 0, 1
count=0

#check if the number of terms is valid 
if nterms == 1:
  print("please enter a positive integer")

#if there is only one term, return n1
elif nterms == 1:
  print("fibanacci sequence upto", nterms, ":")
  print (n1)
#Generate Fibonacci sequence
else:
  print("Fibonacci sequence :")
  while count < nterms :
    print(n1)
    nth = n1 + n3
    #update Values
    n1 = n3
    n3=nth
    count +=1
# Out:
# How many terms??4
# Fibonacci sequence :
# 0
# 1
# 1
# 2

# %%
#BMI Calculator with python 
Height=float(input("Enter your height in centimereter:"))
Weight=float(input("Enter your weight in KG:"))
Height=Height/100
BMI=Weight/(Height*Height)
print("Your Body Mass index is:",BMI)
if(BMI>0):
  if(BMI<=16):
    print("Your are severely undereweight")
  elif(BMI<=18.5):
    print("You are underweight")
  elif(BMI<=25):
    print("you are Healthy")
  elif(BMI<=30):
    print("you are overweight")
  else: 
    print("You are severely overweight")
else:
  print("Enter valid details")
# Out:
# Enter your height in centimereter:180
# Enter your weight in KG:95
# Your Body Mass index is: 29.320987654320987
# you are overweight

# %%
#alphabets pattern in Python 
num=int(input("Enter number of rows:"))
for i in range(97, 97+num):
  for j in range (97,i+1):
    print(chr(i),end='')
  print()
# Out:
# Enter number of rows:5
# a
# bb
# ccc
# dddd
# eeeee

# %%
#bitwise operations on interger Types 
x=6
y=2
print(x|y)
print(x^y)
print(x&y)
print(x<<y)
print(x>>y)
print(-x)
# Out:
# 6
# 4
# 2
# 24
# 1
# -6

# %%
from textblob import TextBlob
def Convert(string):
  li=list(string.split())
  return li
str1=input("Enter your word:")
words=Convert(str1)
corrected_words=[]
for i in words:
  corrected_words.append(TextBlob(i))
print("Wrong Words:",words)
print("Corrected Words are:")

for i in corrected_words:
  print(i.correct(),end=" ")
# Out:
# Enter your word:machn learning
# Wrong Words: ['machn', 'learning']
# Corrected Words are:
# man learning

# %%
import getpass
database = {"Cloding":"97629", "Pythoncloding":"2502"}
username=input("Enter Your Username :")

password =getpass.getpass("Enter your Password :")
for i in database.keys():
  if username  == i:
    while password  != database.get(i):
      password = getpass.getpass("Enter your Password again :")
      break
print("Verified")
# Out:
# Enter Your Username :Cloding
# Enter your Password :··········
# Enter your Password again :··········
# Verified
